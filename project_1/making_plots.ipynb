# %%
#Autorzy kodu: Anna Chojnacka, Michał Puchalski, Paweł Sadłowski

# %%
path = r"E:/ZMS/ZMS"

import csv
import scipy as sc
import matplotlib.pyplot as plt
from scipy.stats.stats import kstest
import numpy as np
from pandas import DataFrame, concat

# %matplotlib inline

# %%
plt.rc('font', size=10)          # controls default text sizes
plt.rc('axes', titlesize=10)     # fontsize of the axes title
plt.rc('axes', labelsize=10)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)    # fontsize of the tick labels
plt.rc('legend', fontsize=10)    # legend fontsize
fullwidth = (5.3, 3.5)

# %%
liczba_szkod = {0 : 3437, 
                1 : 522, 
                2 : 40, 
                3 : 2, 
                4 : 0, 
                5 : 0}

plt.bar(list(liczba_szkod.keys()), 
        list(liczba_szkod.values()))
# Out:
# <Container object of 6 artists>

# %%
# średnia liczbę szkód:
SREDNIA_LICZBA_SZKOD = (sum([x * y for x, y in liczba_szkod.items()]) / 
                        sum(liczba_szkod.values()))

# czy liczba szkód ma faktycznie rozklad Poissona?
poisson_test = [sc.stats.poisson.pmf(i, SREDNIA_LICZBA_SZKOD) * 
                sum(liczba_szkod.values()) for i in range(len(liczba_szkod))]

# %%
fig = plt.figure(figsize = fullwidth)
plt.bar(list(liczba_szkod.keys()), poisson_test, color = "orange")
plt.bar(list(liczba_szkod.keys()), list(liczba_szkod.values()), color = 'blue', width = 0.5)
plt.ylabel('Częstość')
plt.xlabel('Liczba zgłoszonych szkód')
plt.legend(['Rozkład empiryczny', 'Rozkład teoretyczny'])
fig.savefig(path+r'/raport1/wykresy/rozklad_l_szkod.pdf')

# %%
# test chi-kwadrat z biblioteki scipy pomoże odpowiedziec na pytanie:
test1 = sc.stats.chisquare(list(liczba_szkod.values()), f_exp = poisson_test)
if test1[1] > 0.05:
    print ("brak podstaw do odrzucenia hipotezy zerowej")
else:
    print("należy odrzucic hipoteze zerowa")
# Out:
# brak podstaw do odrzucenia hipotezy zerowej

# %%
# ### Wielkość szkód
szkody = []
with open(path+'\\szkody.txt','r') as csvfile:
    reader = csv.reader (csvfile, delimiter=";")
    for row in reader:
        szkody.append(int(row[1]))

plt.hist(szkody, bins=50)
plt.show()

print ("Średnia wielkość szkód:", round(sc.mean(szkody)))
# Out:
# Średnia wielkość szkód: 4742.0

# %%
# wielkość szkód ma rozkład log-normalny:
szkody_ln = sc.log(szkody)

# ... czy faktycznie? test K-S
test2 = kstest(szkody_ln, sc.stats.norm.cdf, 
               args = (sc.mean(szkody_ln), sc.std(szkody_ln)))
if test2[1] > 0.05:
    print ("p-value wyniosło:", round(test2[1], 4), 
           "- brak więc podstaw do odrzucenia hipotezy " +
           "o log-normalności rozkładu zmiennej")
else:
    print ("należy odrzucic hipotezę zerowa")
# Out:
# p-value wyniosło: 0.9979 - brak więc podstaw do odrzucenia hipotezy o log-normalności rozkładu zmiennej

# %%
# parametry wielkości szkód potrzebne do symulacji:
SR_SZKODA_LN = sc.mean(szkody_ln)
STD_SZKODA_LN = sc.std(szkody_ln)

# %%
fig = plt.figure(figsize = fullwidth)
plt.hist(szkody_ln, bins=50, density = True, color = 'orange')
x_norm = np.linspace(min(szkody_ln), max(szkody_ln), 100)
y_norm = sc.stats.norm.pdf(x_norm, SR_SZKODA_LN, STD_SZKODA_LN)
plt.plot(x_norm, y_norm)
plt.legend(['Dopasowany \n r. normalny', 'Histogram rozkładu \n empirycznego'], fontsize = 8, loc = 'upper left')
plt.ylabel('Gęstość masy prawdopodobieństwa')
plt.xlabel('Logarytm wielkości szkody [PLN]')
fig.savefig(path+r'/raport1/wykresy/rozklad_wys_szkody.pdf')

# %%
# ## 2. Model symulacji
def model (liczba_klientow, srednia_liczba_szkod, 
           sr_szkoda_ln, std_szkoda_ln, horyzont, 
           nadwyzka, skladka, seed):
    
    # Common Random Numbers aby moc porownac rozne scenariusze:
    sc.random.seed(seed) 

    # definiujemy daty umów klientow w symulacji:
    daty_umow = [sc.random.randint(0, 364) for i in range(liczba_klientow)]
    kalendarz_wplat = [0]*365
    for dataUmowy in daty_umow:
        kalendarz_wplat[dataUmowy] += 1

    # liczymy liczbe szkód przypadających na jednego klienta:
    liczba_szkod_klienta = sc.random.poisson(srednia_liczba_szkod, 
                                             liczba_klientow)
    
    # i ustalamy daty wyplaty dla wszystkich polis:
    kalendarz_wyplat = [0]*(365*horyzont) 
    for k in range(liczba_klientow):
        for s in range(liczba_szkod_klienta[k]):
            data_wyplaty = daty_umow[k] + sc.random.randint(0, 364)
            kalendarz_wyplat[data_wyplaty] += 1
    
    
    # analiza wyników firmy dla danego horyzontu czasowego i danych szkód:
    for dzien in range(365*horyzont):
        if dzien <= 364:
            nadwyzka += kalendarz_wplat[dzien] * skladka
        liczba_wyplat = kalendarz_wyplat[dzien]
        odszkodowania = 0 
        if liczba_wyplat > 0:
            odszkodowania = sum(sc.exp(sc.random.normal(sr_szkoda_ln, 
                                                        std_szkoda_ln, 
                                                        liczba_wyplat)))
        if nadwyzka < odszkodowania:
            return nadwyzka - odszkodowania
        else:
            pass
        nadwyzka -= odszkodowania
    return nadwyzka


# ### ... i funkcja, która go wywoła *n* razy

# %%
def wywolanie(nadwyzka, skladka, liczba_powtorzen, 
              liczba_klientow, srednia_liczba_szkod , 
              sr_szkoda_ln, std_szkoda_ln, horyzont):
    wynik = []
    bankructwo = 0
    wynik_dodatni = []
    for seed in range(liczba_powtorzen):
        wynik.append(model(liczba_klientow, srednia_liczba_szkod , 
                           sr_szkoda_ln, std_szkoda_ln, horyzont, 
                           nadwyzka, skladka, seed))
        if wynik[seed] < 0:
            bankructwo += 1
        if wynik[seed] > 0:
            wynik_dodatni.append(wynik[seed])
    sredni_wynik = sc.mean(wynik_dodatni)
    odch_stand_wynik = sc.std(wynik_dodatni)
    prawd_bankr = bankructwo / liczba_powtorzen
    return [bankructwo, prawd_bankr, sredni_wynik, odch_stand_wynik]
# Out:
# Nadwyzka:  5000 Skladka:  500 Liczba ruin:  713 Sredni wynik:  13462.0 Prawd_bankr:  0.713
# Nadwyzka:  5000 Skladka:  600 Liczba ruin:  565 Sredni wynik:  17282.0 Prawd_bankr:  0.565
# Nadwyzka:  5000 Skladka:  700 Liczba ruin:  422 Sredni wynik:  21805.0 Prawd_bankr:  0.422
# Nadwyzka:  5000 Skladka:  800 Liczba ruin:  292 Sredni wynik:  27040.0 Prawd_bankr:  0.292
# Nadwyzka:  5000 Skladka:  900 Liczba ruin:  187 Sredni wynik:  33076.0 Prawd_bankr:  0.187
# Nadwyzka:  5000 Skladka:  1000 Liczba ruin:  125 Sredni wynik:  40470.0 Prawd_bankr:  0.125
# Nadwyzka:  5000 Skladka:  1100 Liczba ruin:  70 Sredni wynik:  47927.0 Prawd_bankr:  0.07
# Nadwyzka:  5000 Skladka:  1200 Liczba ruin:  48 Sredni wynik:  56866.0 Prawd_bankr:  0.048
# Nadwyzka:  5000 Skladka:  1300 Liczba ruin:  29 Sredni wynik:  65759.0 Prawd_bankr:  0.029
# Nadwyzka:  5000 Skladka:  1400 Liczba ruin:  23 Sredni wynik:  75426.0 Prawd_bankr:  0.023
# Nadwyzka:  5000 Skladka:  1500 Liczba ruin:  16 Sredni wynik:  84910.0 Prawd_bankr:  0.016
# Nadwyzka:  5000 Skladka:  1600 Liczba ruin:  11 Sredni wynik:  94604.0 Prawd_bankr:  0.011
# Nadwyzka:  5000 Skladka:  1700 Liczba ruin:  10 Sredni wynik:  104506.0 Prawd_bankr:  0.01
# Nadwyzka:  5000 Skladka:  1800 Liczba ruin:  9 Sredni wynik:  114500.0 Prawd_bankr:  0.009
# Nadwyzka:  5000 Skladka:  1900 Liczba ruin:  9 Sredni wynik:  124500.0 Prawd_bankr:  0.009
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8033d3c2a99b> in <module>()
#      42                                  LICZBA_POWTORZEN, LICZBA_KLIENTOW,
#      43                                  SREDNIA_LICZBA_SZKOD , SR_SZKODA_LN,
# ---> 44                                  STD_SZKODA_LN, HORYZONT)
#      45         wysokosc_skladki.append(skladka)
#      46         wysokosc_nadwyzki.append(nadwyzka)
#
# <ipython-input-11-8033d3c2a99b> in wywolanie(nadwyzka, skladka, liczba_powtorzen, liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont)
#       8         wynik.append(model(liczba_klientow, srednia_liczba_szkod ,
#       9                            sr_szkoda_ln, std_szkoda_ln, horyzont,
# ---> 10                            nadwyzka, skladka, seed))
#      11         if wynik[seed] < 0:
#      12             bankructwo += 1
#
# <ipython-input-10-9bfe317e1bd6> in model(liczba_klientow, srednia_liczba_szkod, sr_szkoda_ln, std_szkoda_ln, horyzont, nadwyzka, skladka, seed)
#      19     # liczymy liczbe szkód przypadających na jednego klienta:
#      20     liczba_szkod_klienta = sc.random.poisson(srednia_liczba_szkod,
# ---> 21                                              liczba_klientow)
#      22
#      23     # i ustalamy daty wyplaty dla wszystkich polis:
#
# KeyboardInterrupt:

# %%
# ## 3. Symulacja

# zmienne i parametry w modelu:
sr_wynik = [] # średni wynik finansowy firmy
odch_stand_wynik = [] # Odch. stand. sredniego wyniku
wysokosc_skladki = []
wysokosc_nadwyzki = []
prawd_bankr = []
liczba_ruin = [] 

LICZBA_POWTORZEN = 1000
LICZBA_KLIENTOW = 100
HORYZONT = 2 # dlugość obowiązywania umowy - zakładamy 2 lata


for nadwyzka in range(5000, 21000, 1000):
    for skladka in range(500, 2100, 100):
        wartosc_f_xy = wywolanie(nadwyzka, skladka, 
                                 LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
                                 SREDNIA_LICZBA_SZKOD , SR_SZKODA_LN, 
                                 STD_SZKODA_LN, HORYZONT)
        wysokosc_skladki.append(skladka)
        wysokosc_nadwyzki.append(nadwyzka)
        liczba_ruin.append(wartosc_f_xy[0])
        prawd_bankr.append(wartosc_f_xy[1])
        sr_wynik.append(wartosc_f_xy[2])
        odch_stand_wynik.append(wartosc_f_xy[3])
        print("Nadwyzka: ", nadwyzka, "Skladka: ", skladka, 
              "Liczba ruin: ", wartosc_f_xy[0], "Sredni wynik: ",
              round(wartosc_f_xy[2]), "Prawd_bankr: ", wartosc_f_xy[1])

dane = DataFrame.from_dict({'nadwyzka': wysokosc_nadwyzki,
                            'skladka': wysokosc_skladki,
                            'liczba_ruin': liczba_ruin,
                            'prawd_bankr': prawd_bankr,
                            'sr_wynik': sr_wynik,
                            'odch_stand_wynik': odch_stand_wynik},
        orient = 'columns')

dane.set_index(['nadwyzka', 'skladka'], inplace = True)

# %%
fig, ax = plt.subplots(figsize = fullwidth)
dane.loc[(10000,slice(None)),'prawd_bankr'].reset_index(). \
    plot(x = 'skladka', y = 'prawd_bankr', legend = False, ax = ax)
ax.set_xlabel('Wysokość składki [PLN]')
ax.set_ylabel('Prawdopodobieństwo bankructwa')
fig.savefig(path+r'\raport1\wykresy\p_bankructwa.pdf')

# %%
fig, ax = plt.subplots(figsize = fullwidth)
dane.loc[(list(range(6000,10000,2000)), slice(None)),'prawd_bankr'].reset_index().groupby('nadwyzka'). \
    plot(x = 'skladka', y = 'prawd_bankr', ax = ax)
dane.loc[(10000, slice(None)), 'prawd_bankr'].reset_index().plot(x = 'skladka', y = 'prawd_bankr', ax = ax,
                                                                color = 'k', linewidth = 3)
dane.loc[(list(range(12000,22000,2000)), slice(None)),'prawd_bankr'].reset_index().groupby('nadwyzka'). \
    plot(x = 'skladka', y = 'prawd_bankr', ax = ax)
ax.set_xlabel('Wysokość składki [PLN]')
ax.set_ylabel('Prawdopodobieństwo bankructwa')
ax.legend(labels = [str(x) for x in range(6000, 22000, 2000)], title = 'Nadwyżka [PLN]', fontsize = 8)
ax.axhline(y = 0.01, color = 'k' , linestyle = '--')
fig.savefig(path+r'\raport1\wykresy\p_bankructwa_porownanie.pdf')

# %%
df2 = (dane.pivot_table(index='nadwyzka', columns='skladka', values='prawd_bankr').reset_index())

fig = plt.figure(figsize=(6.4,4.8))
heatmap = plt.pcolor(df2.iloc[:, 1:], cmap='gnuplot2')
plt.yticks(np.arange(0.5, len(df2.iloc[:,0]), 1), df2.iloc[:,0], fontsize = 8)
plt.xticks(np.arange(0.5, len(df2.columns[1:]), 1), df2.columns[1:], fontsize = 8, rotation = 45)
plt.xlabel('Wysokość składki [PLN]')
plt.ylabel('Nadwyżka początkowa[PLN]')
plt.colorbar(heatmap)
plt.show()

fig.savefig(path+r'/raport1/wykresy/p_heatmapa_bankructwo.pdf')

# %%
fig = plt.figure(figsize = (6.4,4.8))
heatmap = plt.pcolor(df2.iloc[:, 1:] <= 0.01, cmap='gnuplot2')
plt.yticks(np.arange(0.5, len(df2.iloc[:,0]), 1), df2.iloc[:,0], fontsize = 8)
plt.xticks(np.arange(0.5, len(df2.columns[1:]), 1), df2.columns[1:], fontsize = 8, rotation = 45)
plt.xlabel('Wysokość składki [PLN]')
plt.ylabel('Nadwyżka początkowa [PLN]')
plt.show()

fig.savefig(path+r'/raport1/wykresy/p_heatmapa_bankructwo_mniej_niz_0,01.pdf')

# %%
# ## RAPORT 
# 
# ### Zbadaj płynność firmy w zależności od parametrów
# 
# **Pytania**
# 1. Jaką ustalić składkę OC, aby ruina kierowców nie była udziałem PiTU S.A.?
# 2. Czy nadwyżka końcowa będzie równa początkowej?
# 3. Jakie jest zagrożenie ruiną?
# 4. Jaka powinna być nadwyżka i składka, żeby prawdopodobieństwo ruiny było mniejsze niż 0,01?
# 5. Jak liczba symulacji wpływa na wyniki?

# %%
# Wykres sredniej koncowej nadwyzki dodatniej

plotdata = dane.loc[(10000, slice(None)),['sr_wynik', 'odch_stand_wynik']]
plotdata['upper'] = plotdata.sr_wynik + plotdata.odch_stand_wynik
plotdata['lower'] = plotdata.sr_wynik - plotdata.odch_stand_wynik

fig, ax = plt.subplots(figsize = fullwidth)
plotdata.reset_index().plot(x = 'skladka', y = 'upper', legend = False,
                    ax = ax, kind = 'area', color = 'blue', alpha = 0.2)
plotdata.reset_index().plot(x = 'skladka', y = 'lower', legend = False,
                    ax = ax, kind = 'area', color = 'white')
plotdata.reset_index().plot(x = 'skladka', y = ['sr_wynik', 'upper', 'lower'],
                    legend = False, ax = ax, style = ['b', '--k', '--k'])
ax.set_xlabel('Wysokość składki [PLN]')
ax.set_ylabel('Średnia nadwyżka końcowa [PLN]')
fig.savefig(path+r'/raport1/wykresy/nadwyzka.pdf')

# %%
# ## 3. Symulacja

# zmienne i parametry w modelu:
sr_wynik = [] # średni wynik finansowy firmy
odch_stand_wynik = [] # Odch. stand. sredniego wyniku
wysokosc_skladki = []
wysokosc_nadwyzki = []
prawd_bankr = []
liczba_ruin = [] 

LICZBA_POWTORZEN = 1000
LICZBA_KLIENTOW = 100
HORYZONT = 2 # dlugość obowiązywania umowy - zakładamy 2 lata


for nadwyzka in range(5000, 21000, 1000):
    for skladka in range(500, 2100, 100):
        wartosc_f_xy = wywolanie(nadwyzka, skladka, 
                                 LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
                                 SREDNIA_LICZBA_SZKOD , SR_SZKODA_LN, 
                                 STD_SZKODA_LN, HORYZONT)
        wysokosc_skladki.append(skladka)
        wysokosc_nadwyzki.append(nadwyzka)
        liczba_ruin.append(wartosc_f_xy[0])
        prawd_bankr.append(wartosc_f_xy[1])
        sr_wynik.append(wartosc_f_xy[2])
        odch_stand_wynik.append(wartosc_f_xy[3])
        print("Nadwyzka: ", nadwyzka, "Skladka: ", skladka, 
              "Liczba ruin: ", wartosc_f_xy[0], "Sredni wynik: ",
              round(wartosc_f_xy[2]), "Prawd_bankr: ", wartosc_f_xy[1])

lambda_up = DataFrame.from_dict({'nadwyzka': wysokosc_nadwyzki,
                            'skladka': wysokosc_skladki,
                            'liczba_ruin': liczba_ruin,
                            'prawd_bankr': prawd_bankr,
                            'sr_wynik': sr_wynik,
                            'odch_stand_wynik': odch_stand_wynik},
        orient = 'columns')

lambda_up.set_index(['nadwyzka', 'skladka'], inplace = True)

# %%
# ## 3. Symulacja

# zmienne i parametry w modelu:
sr_wynik = [] # średni wynik finansowy firmy
odch_stand_wynik = [] # Odch. stand. sredniego wyniku
wysokosc_skladki = []
wysokosc_nadwyzki = []
prawd_bankr = []
liczba_ruin = [] 

LICZBA_POWTORZEN = 1000
LICZBA_KLIENTOW = 100
HORYZONT = 2 # dlugość obowiązywania umowy - zakładamy 2 lata


for nadwyzka in range(5000, 21000, 1000):
    for skladka in range(500, 2100, 100):
        wartosc_f_xy = wywolanie(nadwyzka, skladka, 
                                 LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
                                 SREDNIA_LICZBA_SZKOD , SR_SZKODA_LN, 
                                 STD_SZKODA_LN, HORYZONT)
        wysokosc_skladki.append(skladka)
        wysokosc_nadwyzki.append(nadwyzka)
        liczba_ruin.append(wartosc_f_xy[0])
        prawd_bankr.append(wartosc_f_xy[1])
        sr_wynik.append(wartosc_f_xy[2])
        odch_stand_wynik.append(wartosc_f_xy[3])
        print("Nadwyzka: ", nadwyzka, "Skladka: ", skladka, 
              "Liczba ruin: ", wartosc_f_xy[0], "Sredni wynik: ",
              round(wartosc_f_xy[2]), "Prawd_bankr: ", wartosc_f_xy[1])

lambda_down = DataFrame.from_dict({'nadwyzka': wysokosc_nadwyzki,
                            'skladka': wysokosc_skladki,
                            'liczba_ruin': liczba_ruin,
                            'prawd_bankr': prawd_bankr,
                            'sr_wynik': sr_wynik,
                            'odch_stand_wynik': odch_stand_wynik},
        orient = 'columns')

lambda_down.set_index(['nadwyzka', 'skladka'], inplace = True)

# %%
df = concat([dane, lambda_up, lambda_down], keys = ['bazowy', 'plus', 'minus'], names = ['scenariusz'])

# %%
fig, ax = plt.subplots(figsize = fullwidth)
for k,v in {10000:'blue', 20000:'orange'}.items():
    df.loc[('bazowy', k, slice(None)),:].reset_index(). \
        plot(x = 'skladka', y = 'prawd_bankr', color = v, ax = ax, legend = False)
    df.loc[(['plus', 'minus'], k, slice(None)),:].reset_index().groupby('scenariusz'). \
        plot(x = 'skladka', y = 'prawd_bankr', color = v, style = '--', ax = ax, legend = False)
ax.set_xlabel('Wysokość składki')
ax.set_ylabel('Prawdopodobieństwo bankructwa')
ax.axhline(y = 0.01, color = 'k', linestyle = '-.')
ax.legend(labels = [x+'PLN, '+y for x in ['10,000', '20,000'] \
                    for y in [r'$\lambda$', r'$1.05 * \lambda$', r'$0.95 * \lambda$']],
         title = 'Nadwyżka, scenariusz', fontsize = 8)
fig.savefig(path+r'/raport1/wykresy/p_bankructwa_all.pdf')

# %%
# Powtorka symulacji, lambda +5%
sr_wynik = [] # średni wynik finansowy firmy
odch_stand_wynik = [] # Odch. stand. sredniego wyniku
wysokosc_skladki = []
wysokosc_nadwyzki = []
prawd_bankr = []
liczba_ruin = [] 

LICZBA_POWTORZEN = 1500
LICZBA_KLIENTOW = 100
HORYZONT = 2 # dlugość obowiązywania umowy - zakładamy 2 lata


for nadwyzka in range(5000, 21000, 1000):
    for skladka in range(500, 2100, 100):
        wartosc_f_xy = wywolanie(nadwyzka, skladka, 
                                 LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
                                 SREDNIA_LICZBA_SZKOD , SR_SZKODA_LN, 
                                 STD_SZKODA_LN, HORYZONT)
        wysokosc_skladki.append(skladka)
        wysokosc_nadwyzki.append(nadwyzka)
        liczba_ruin.append(wartosc_f_xy[0])
        prawd_bankr.append(wartosc_f_xy[1])
        sr_wynik.append(wartosc_f_xy[2])
        odch_stand_wynik.append(wartosc_f_xy[3])
        print("Nadwyzka: ", nadwyzka, "Skladka: ", skladka, 
              "Liczba ruin: ", wartosc_f_xy[0], "Sredni wynik: ",
              round(wartosc_f_xy[2]), "Prawd_bankr: ", wartosc_f_xy[1])

piecset = DataFrame.from_dict({'nadwyzka': wysokosc_nadwyzki,
                            'skladka': wysokosc_skladki,
                            'liczba_ruin': liczba_ruin,
                            'prawd_bankr': prawd_bankr,
                            'sr_wynik': sr_wynik,
                            'odch_stand_wynik': odch_stand_wynik},
        orient = 'columns')

piecset.set_index(['nadwyzka', 'skladka'], inplace = True)
# Out:
# Nadwyzka:  5000 Skladka:  500 Liczba ruin:  1060 Sredni wynik:  13618.0 Prawd_bankr:  0.7066666666666667
# Nadwyzka:  5000 Skladka:  600 Liczba ruin:  846 Sredni wynik:  17566.0 Prawd_bankr:  0.564
# Nadwyzka:  5000 Skladka:  700 Liczba ruin:  643 Sredni wynik:  22276.0 Prawd_bankr:  0.42866666666666664
# Nadwyzka:  5000 Skladka:  800 Liczba ruin:  447 Sredni wynik:  27370.0 Prawd_bankr:  0.298
# Nadwyzka:  5000 Skladka:  900 Liczba ruin:  288 Sredni wynik:  33350.0 Prawd_bankr:  0.192
# Nadwyzka:  5000 Skladka:  1000 Liczba ruin:  194 Sredni wynik:  40677.0 Prawd_bankr:  0.12933333333333333
# Nadwyzka:  5000 Skladka:  1100 Liczba ruin:  120 Sredni wynik:  48402.0 Prawd_bankr:  0.08
# Nadwyzka:  5000 Skladka:  1200 Liczba ruin:  84 Sredni wynik:  57147.0 Prawd_bankr:  0.056
# Nadwyzka:  5000 Skladka:  1300 Liczba ruin:  53 Sredni wynik:  65942.0 Prawd_bankr:  0.035333333333333335
# Nadwyzka:  5000 Skladka:  1400 Liczba ruin:  36 Sredni wynik:  75256.0 Prawd_bankr:  0.024
# Nadwyzka:  5000 Skladka:  1500 Liczba ruin:  24 Sredni wynik:  84728.0 Prawd_bankr:  0.016
# Nadwyzka:  5000 Skladka:  1600 Liczba ruin:  19 Sredni wynik:  94525.0 Prawd_bankr:  0.012666666666666666
# Nadwyzka:  5000 Skladka:  1700 Liczba ruin:  13 Sredni wynik:  104210.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  5000 Skladka:  1800 Liczba ruin:  12 Sredni wynik:  114206.0 Prawd_bankr:  0.008
# Nadwyzka:  5000 Skladka:  1900 Liczba ruin:  10 Sredni wynik:  124129.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  5000 Skladka:  2000 Liczba ruin:  7 Sredni wynik:  133962.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  6000 Skladka:  500 Liczba ruin:  1040 Sredni wynik:  14004.0 Prawd_bankr:  0.6933333333333334
# Nadwyzka:  6000 Skladka:  600 Liczba ruin:  827 Sredni wynik:  18076.0 Prawd_bankr:  0.5513333333333333
# Nadwyzka:  6000 Skladka:  700 Liczba ruin:  612 Sredni wynik:  22501.0 Prawd_bankr:  0.408
# Nadwyzka:  6000 Skladka:  800 Liczba ruin:  423 Sredni wynik:  27926.0 Prawd_bankr:  0.282
# Nadwyzka:  6000 Skladka:  900 Liczba ruin:  274 Sredni wynik:  34010.0 Prawd_bankr:  0.18266666666666667
# Nadwyzka:  6000 Skladka:  1000 Liczba ruin:  182 Sredni wynik:  41441.0 Prawd_bankr:  0.12133333333333333
# Nadwyzka:  6000 Skladka:  1100 Liczba ruin:  111 Sredni wynik:  49179.0 Prawd_bankr:  0.074
# Nadwyzka:  6000 Skladka:  1200 Liczba ruin:  80 Sredni wynik:  58056.0 Prawd_bankr:  0.05333333333333334
# Nadwyzka:  6000 Skladka:  1300 Liczba ruin:  48 Sredni wynik:  66818.0 Prawd_bankr:  0.032
# Nadwyzka:  6000 Skladka:  1400 Liczba ruin:  33 Sredni wynik:  76217.0 Prawd_bankr:  0.022
# Nadwyzka:  6000 Skladka:  1500 Liczba ruin:  20 Sredni wynik:  85586.0 Prawd_bankr:  0.013333333333333334
# Nadwyzka:  6000 Skladka:  1600 Liczba ruin:  17 Sredni wynik:  95505.0 Prawd_bankr:  0.011333333333333334
# Nadwyzka:  6000 Skladka:  1700 Liczba ruin:  11 Sredni wynik:  105214.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  6000 Skladka:  1800 Liczba ruin:  10 Sredni wynik:  115169.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  6000 Skladka:  1900 Liczba ruin:  9 Sredni wynik:  125137.0 Prawd_bankr:  0.006
# Nadwyzka:  6000 Skladka:  2000 Liczba ruin:  7 Sredni wynik:  134962.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  7000 Skladka:  500 Liczba ruin:  1016 Sredni wynik:  14284.0 Prawd_bankr:  0.6773333333333333
# Nadwyzka:  7000 Skladka:  600 Liczba ruin:  800 Sredni wynik:  18438.0 Prawd_bankr:  0.5333333333333333
# Nadwyzka:  7000 Skladka:  700 Liczba ruin:  580 Sredni wynik:  22818.0 Prawd_bankr:  0.38666666666666666
# Nadwyzka:  7000 Skladka:  800 Liczba ruin:  405 Sredni wynik:  28563.0 Prawd_bankr:  0.27
# Nadwyzka:  7000 Skladka:  900 Liczba ruin:  260 Sredni wynik:  34683.0 Prawd_bankr:  0.17333333333333334
# Nadwyzka:  7000 Skladka:  1000 Liczba ruin:  171 Sredni wynik:  42176.0 Prawd_bankr:  0.114
# Nadwyzka:  7000 Skladka:  1100 Liczba ruin:  108 Sredni wynik:  50132.0 Prawd_bankr:  0.072
# Nadwyzka:  7000 Skladka:  1200 Liczba ruin:  77 Sredni wynik:  58991.0 Prawd_bankr:  0.051333333333333335
# Nadwyzka:  7000 Skladka:  1300 Liczba ruin:  41 Sredni wynik:  67646.0 Prawd_bankr:  0.027333333333333334
# Nadwyzka:  7000 Skladka:  1400 Liczba ruin:  30 Sredni wynik:  77121.0 Prawd_bankr:  0.02
# Nadwyzka:  7000 Skladka:  1500 Liczba ruin:  18 Sredni wynik:  86567.0 Prawd_bankr:  0.012
# Nadwyzka:  7000 Skladka:  1600 Liczba ruin:  14 Sredni wynik:  96414.0 Prawd_bankr:  0.009333333333333334
# Nadwyzka:  7000 Skladka:  1700 Liczba ruin:  11 Sredni wynik:  106214.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  7000 Skladka:  1800 Liczba ruin:  9 Sredni wynik:  116137.0 Prawd_bankr:  0.006
# Nadwyzka:  7000 Skladka:  1900 Liczba ruin:  8 Sredni wynik:  126145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  7000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  135970.0 Prawd_bankr:  0.004
# Nadwyzka:  8000 Skladka:  500 Liczba ruin:  989 Sredni wynik:  14558.0 Prawd_bankr:  0.6593333333333333
# Nadwyzka:  8000 Skladka:  600 Liczba ruin:  785 Sredni wynik:  19116.0 Prawd_bankr:  0.5233333333333333
# Nadwyzka:  8000 Skladka:  700 Liczba ruin:  554 Sredni wynik:  23267.0 Prawd_bankr:  0.36933333333333335
# Nadwyzka:  8000 Skladka:  800 Liczba ruin:  386 Sredni wynik:  29071.0 Prawd_bankr:  0.25733333333333336
# Nadwyzka:  8000 Skladka:  900 Liczba ruin:  247 Sredni wynik:  35349.0 Prawd_bankr:  0.16466666666666666
# Nadwyzka:  8000 Skladka:  1000 Liczba ruin:  163 Sredni wynik:  43008.0 Prawd_bankr:  0.10866666666666666
# Nadwyzka:  8000 Skladka:  1100 Liczba ruin:  101 Sredni wynik:  50966.0 Prawd_bankr:  0.06733333333333333
# Nadwyzka:  8000 Skladka:  1200 Liczba ruin:  69 Sredni wynik:  59824.0 Prawd_bankr:  0.046
# Nadwyzka:  8000 Skladka:  1300 Liczba ruin:  41 Sredni wynik:  68646.0 Prawd_bankr:  0.027333333333333334
# Nadwyzka:  8000 Skladka:  1400 Liczba ruin:  28 Sredni wynik:  78076.0 Prawd_bankr:  0.018666666666666668
# Nadwyzka:  8000 Skladka:  1500 Liczba ruin:  17 Sredni wynik:  87562.0 Prawd_bankr:  0.011333333333333334
# Nadwyzka:  8000 Skladka:  1600 Liczba ruin:  14 Sredni wynik:  97414.0 Prawd_bankr:  0.009333333333333334
# Nadwyzka:  8000 Skladka:  1700 Liczba ruin:  11 Sredni wynik:  107214.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  8000 Skladka:  1800 Liczba ruin:  8 Sredni wynik:  117145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  8000 Skladka:  1900 Liczba ruin:  7 Sredni wynik:  127060.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  8000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  136970.0 Prawd_bankr:  0.004
# Nadwyzka:  9000 Skladka:  500 Liczba ruin:  965 Sredni wynik:  14966.0 Prawd_bankr:  0.6433333333333333
# Nadwyzka:  9000 Skladka:  600 Liczba ruin:  757 Sredni wynik:  19405.0 Prawd_bankr:  0.5046666666666667
# Nadwyzka:  9000 Skladka:  700 Liczba ruin:  533 Sredni wynik:  23777.0 Prawd_bankr:  0.35533333333333333
# Nadwyzka:  9000 Skladka:  800 Liczba ruin:  372 Sredni wynik:  29731.0 Prawd_bankr:  0.248
# Nadwyzka:  9000 Skladka:  900 Liczba ruin:  227 Sredni wynik:  35879.0 Prawd_bankr:  0.15133333333333332
# Nadwyzka:  9000 Skladka:  1000 Liczba ruin:  154 Sredni wynik:  43759.0 Prawd_bankr:  0.10266666666666667
# Nadwyzka:  9000 Skladka:  1100 Liczba ruin:  93 Sredni wynik:  51736.0 Prawd_bankr:  0.062
# Nadwyzka:  9000 Skladka:  1200 Liczba ruin:  63 Sredni wynik:  60616.0 Prawd_bankr:  0.042
# Nadwyzka:  9000 Skladka:  1300 Liczba ruin:  38 Sredni wynik:  69539.0 Prawd_bankr:  0.025333333333333333
# Nadwyzka:  9000 Skladka:  1400 Liczba ruin:  26 Sredni wynik:  78999.0 Prawd_bankr:  0.017333333333333333
# Nadwyzka:  9000 Skladka:  1500 Liczba ruin:  16 Sredni wynik:  88540.0 Prawd_bankr:  0.010666666666666666
# Nadwyzka:  9000 Skladka:  1600 Liczba ruin:  12 Sredni wynik:  98356.0 Prawd_bankr:  0.008
# Nadwyzka:  9000 Skladka:  1700 Liczba ruin:  10 Sredni wynik:  108221.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  9000 Skladka:  1800 Liczba ruin:  8 Sredni wynik:  118145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  9000 Skladka:  1900 Liczba ruin:  7 Sredni wynik:  128060.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  9000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  137970.0 Prawd_bankr:  0.004
# Nadwyzka:  10000 Skladka:  500 Liczba ruin:  944 Sredni wynik:  15381.0 Prawd_bankr:  0.6293333333333333
# Nadwyzka:  10000 Skladka:  600 Liczba ruin:  738 Sredni wynik:  19938.0 Prawd_bankr:  0.492
# Nadwyzka:  10000 Skladka:  700 Liczba ruin:  516 Sredni wynik:  24383.0 Prawd_bankr:  0.344
# Nadwyzka:  10000 Skladka:  800 Liczba ruin:  350 Sredni wynik:  30211.0 Prawd_bankr:  0.23333333333333334
# Nadwyzka:  10000 Skladka:  900 Liczba ruin:  217 Sredni wynik:  36656.0 Prawd_bankr:  0.14466666666666667
# Nadwyzka:  10000 Skladka:  1000 Liczba ruin:  142 Sredni wynik:  44419.0 Prawd_bankr:  0.09466666666666666
# Nadwyzka:  10000 Skladka:  1100 Liczba ruin:  91 Sredni wynik:  52662.0 Prawd_bankr:  0.06066666666666667
# Nadwyzka:  10000 Skladka:  1200 Liczba ruin:  59 Sredni wynik:  61460.0 Prawd_bankr:  0.03933333333333333
# Nadwyzka:  10000 Skladka:  1300 Liczba ruin:  35 Sredni wynik:  70395.0 Prawd_bankr:  0.023333333333333334
# Nadwyzka:  10000 Skladka:  1400 Liczba ruin:  25 Sredni wynik:  79994.0 Prawd_bankr:  0.016666666666666666
# Nadwyzka:  10000 Skladka:  1500 Liczba ruin:  15 Sredni wynik:  89548.0 Prawd_bankr:  0.01
# Nadwyzka:  10000 Skladka:  1600 Liczba ruin:  12 Sredni wynik:  99356.0 Prawd_bankr:  0.008
# Nadwyzka:  10000 Skladka:  1700 Liczba ruin:  9 Sredni wynik:  109189.0 Prawd_bankr:  0.006
# Nadwyzka:  10000 Skladka:  1800 Liczba ruin:  8 Sredni wynik:  119145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  10000 Skladka:  1900 Liczba ruin:  7 Sredni wynik:  129060.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  10000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  138970.0 Prawd_bankr:  0.004
# Nadwyzka:  11000 Skladka:  500 Liczba ruin:  926 Sredni wynik:  15898.0 Prawd_bankr:  0.6173333333333333
# Nadwyzka:  11000 Skladka:  600 Liczba ruin:  712 Sredni wynik:  20298.0 Prawd_bankr:  0.4746666666666667
# Nadwyzka:  11000 Skladka:  700 Liczba ruin:  494 Sredni wynik:  24850.0 Prawd_bankr:  0.3293333333333333
# Nadwyzka:  11000 Skladka:  800 Liczba ruin:  333 Sredni wynik:  30793.0 Prawd_bankr:  0.222
# Nadwyzka:  11000 Skladka:  900 Liczba ruin:  202 Sredni wynik:  37261.0 Prawd_bankr:  0.13466666666666666
# Nadwyzka:  11000 Skladka:  1000 Liczba ruin:  136 Sredni wynik:  45222.0 Prawd_bankr:  0.09066666666666667
# Nadwyzka:  11000 Skladka:  1100 Liczba ruin:  87 Sredni wynik:  53548.0 Prawd_bankr:  0.058
# Nadwyzka:  11000 Skladka:  1200 Liczba ruin:  57 Sredni wynik:  62374.0 Prawd_bankr:  0.038
# Nadwyzka:  11000 Skladka:  1300 Liczba ruin:  32 Sredni wynik:  71324.0 Prawd_bankr:  0.021333333333333333
# Nadwyzka:  11000 Skladka:  1400 Liczba ruin:  21 Sredni wynik:  80884.0 Prawd_bankr:  0.014
# Nadwyzka:  11000 Skladka:  1500 Liczba ruin:  15 Sredni wynik:  90548.0 Prawd_bankr:  0.01
# Nadwyzka:  11000 Skladka:  1600 Liczba ruin:  11 Sredni wynik:  100289.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  11000 Skladka:  1700 Liczba ruin:  8 Sredni wynik:  110145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  11000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  120134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  11000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  130049.0 Prawd_bankr:  0.004
# Nadwyzka:  11000 Skladka:  2000 Liczba ruin:  5 Sredni wynik:  139960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  12000 Skladka:  500 Liczba ruin:  905 Sredni wynik:  16320.0 Prawd_bankr:  0.6033333333333334
# Nadwyzka:  12000 Skladka:  600 Liczba ruin:  690 Sredni wynik:  20742.0 Prawd_bankr:  0.46
# Nadwyzka:  12000 Skladka:  700 Liczba ruin:  475 Sredni wynik:  25428.0 Prawd_bankr:  0.31666666666666665
# Nadwyzka:  12000 Skladka:  800 Liczba ruin:  317 Sredni wynik:  31396.0 Prawd_bankr:  0.21133333333333335
# Nadwyzka:  12000 Skladka:  900 Liczba ruin:  191 Sredni wynik:  37957.0 Prawd_bankr:  0.12733333333333333
# Nadwyzka:  12000 Skladka:  1000 Liczba ruin:  129 Sredni wynik:  45989.0 Prawd_bankr:  0.086
# Nadwyzka:  12000 Skladka:  1100 Liczba ruin:  86 Sredni wynik:  54518.0 Prawd_bankr:  0.05733333333333333
# Nadwyzka:  12000 Skladka:  1200 Liczba ruin:  53 Sredni wynik:  63258.0 Prawd_bankr:  0.035333333333333335
# Nadwyzka:  12000 Skladka:  1300 Liczba ruin:  29 Sredni wynik:  72271.0 Prawd_bankr:  0.019333333333333334
# Nadwyzka:  12000 Skladka:  1400 Liczba ruin:  19 Sredni wynik:  81819.0 Prawd_bankr:  0.012666666666666666
# Nadwyzka:  12000 Skladka:  1500 Liczba ruin:  13 Sredni wynik:  91476.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  12000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  101178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  12000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  111134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  12000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  121134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  12000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  131049.0 Prawd_bankr:  0.004
# Nadwyzka:  12000 Skladka:  2000 Liczba ruin:  5 Sredni wynik:  140960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  13000 Skladka:  500 Liczba ruin:  875 Sredni wynik:  16515.0 Prawd_bankr:  0.5833333333333334
# Nadwyzka:  13000 Skladka:  600 Liczba ruin:  668 Sredni wynik:  21205.0 Prawd_bankr:  0.44533333333333336
# Nadwyzka:  13000 Skladka:  700 Liczba ruin:  460 Sredni wynik:  26056.0 Prawd_bankr:  0.30666666666666664
# Nadwyzka:  13000 Skladka:  800 Liczba ruin:  300 Sredni wynik:  31971.0 Prawd_bankr:  0.2
# Nadwyzka:  13000 Skladka:  900 Liczba ruin:  188 Sredni wynik:  38881.0 Prawd_bankr:  0.12533333333333332
# Nadwyzka:  13000 Skladka:  1000 Liczba ruin:  116 Sredni wynik:  46600.0 Prawd_bankr:  0.07733333333333334
# Nadwyzka:  13000 Skladka:  1100 Liczba ruin:  79 Sredni wynik:  55347.0 Prawd_bankr:  0.05266666666666667
# Nadwyzka:  13000 Skladka:  1200 Liczba ruin:  48 Sredni wynik:  64145.0 Prawd_bankr:  0.032
# Nadwyzka:  13000 Skladka:  1300 Liczba ruin:  27 Sredni wynik:  73198.0 Prawd_bankr:  0.018
# Nadwyzka:  13000 Skladka:  1400 Liczba ruin:  17 Sredni wynik:  82707.0 Prawd_bankr:  0.011333333333333334
# Nadwyzka:  13000 Skladka:  1500 Liczba ruin:  13 Sredni wynik:  92476.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  13000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  102178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  13000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  112134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  13000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  122134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  13000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  132049.0 Prawd_bankr:  0.004
# Nadwyzka:  13000 Skladka:  2000 Liczba ruin:  5 Sredni wynik:  141960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  14000 Skladka:  500 Liczba ruin:  853 Sredni wynik:  16938.0 Prawd_bankr:  0.5686666666666667
# Nadwyzka:  14000 Skladka:  600 Liczba ruin:  653 Sredni wynik:  21821.0 Prawd_bankr:  0.43533333333333335
# Nadwyzka:  14000 Skladka:  700 Liczba ruin:  442 Sredni wynik:  26628.0 Prawd_bankr:  0.2946666666666667
# Nadwyzka:  14000 Skladka:  800 Liczba ruin:  284 Sredni wynik:  32544.0 Prawd_bankr:  0.18933333333333333
# Nadwyzka:  14000 Skladka:  900 Liczba ruin:  183 Sredni wynik:  39765.0 Prawd_bankr:  0.122
# Nadwyzka:  14000 Skladka:  1000 Liczba ruin:  108 Sredni wynik:  47367.0 Prawd_bankr:  0.072
# Nadwyzka:  14000 Skladka:  1100 Liczba ruin:  74 Sredni wynik:  56184.0 Prawd_bankr:  0.04933333333333333
# Nadwyzka:  14000 Skladka:  1200 Liczba ruin:  45 Sredni wynik:  65032.0 Prawd_bankr:  0.03
# Nadwyzka:  14000 Skladka:  1300 Liczba ruin:  25 Sredni wynik:  74125.0 Prawd_bankr:  0.016666666666666666
# Nadwyzka:  14000 Skladka:  1400 Liczba ruin:  16 Sredni wynik:  83651.0 Prawd_bankr:  0.010666666666666666
# Nadwyzka:  14000 Skladka:  1500 Liczba ruin:  12 Sredni wynik:  93443.0 Prawd_bankr:  0.008
# Nadwyzka:  14000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  103178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  14000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  113134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  14000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  123134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  14000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  133049.0 Prawd_bankr:  0.004
# Nadwyzka:  14000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  142896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  15000 Skladka:  500 Liczba ruin:  833 Sredni wynik:  17439.0 Prawd_bankr:  0.5553333333333333
# Nadwyzka:  15000 Skladka:  600 Liczba ruin:  625 Sredni wynik:  22134.0 Prawd_bankr:  0.4166666666666667
# Nadwyzka:  15000 Skladka:  700 Liczba ruin:  426 Sredni wynik:  27238.0 Prawd_bankr:  0.284
# Nadwyzka:  15000 Skladka:  800 Liczba ruin:  270 Sredni wynik:  33196.0 Prawd_bankr:  0.18
# Nadwyzka:  15000 Skladka:  900 Liczba ruin:  176 Sredni wynik:  40554.0 Prawd_bankr:  0.11733333333333333
# Nadwyzka:  15000 Skladka:  1000 Liczba ruin:  103 Sredni wynik:  48222.0 Prawd_bankr:  0.06866666666666667
# Nadwyzka:  15000 Skladka:  1100 Liczba ruin:  69 Sredni wynik:  56987.0 Prawd_bankr:  0.046
# Nadwyzka:  15000 Skladka:  1200 Liczba ruin:  38 Sredni wynik:  65718.0 Prawd_bankr:  0.025333333333333333
# Nadwyzka:  15000 Skladka:  1300 Liczba ruin:  25 Sredni wynik:  75125.0 Prawd_bankr:  0.016666666666666666
# Nadwyzka:  15000 Skladka:  1400 Liczba ruin:  15 Sredni wynik:  84594.0 Prawd_bankr:  0.01
# Nadwyzka:  15000 Skladka:  1500 Liczba ruin:  12 Sredni wynik:  94443.0 Prawd_bankr:  0.008
# Nadwyzka:  15000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  104178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  15000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  114134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  15000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  124134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  15000 Skladka:  1900 Liczba ruin:  5 Sredni wynik:  133960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  15000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  143896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  16000 Skladka:  500 Liczba ruin:  812 Sredni wynik:  17894.0 Prawd_bankr:  0.5413333333333333
# Nadwyzka:  16000 Skladka:  600 Liczba ruin:  595 Sredni wynik:  22381.0 Prawd_bankr:  0.39666666666666667
# Nadwyzka:  16000 Skladka:  700 Liczba ruin:  408 Sredni wynik:  27808.0 Prawd_bankr:  0.272
# Nadwyzka:  16000 Skladka:  800 Liczba ruin:  258 Sredni wynik:  33879.0 Prawd_bankr:  0.172
# Nadwyzka:  16000 Skladka:  900 Liczba ruin:  168 Sredni wynik:  41330.0 Prawd_bankr:  0.112
# Nadwyzka:  16000 Skladka:  1000 Liczba ruin:  97 Sredni wynik:  49014.0 Prawd_bankr:  0.06466666666666666
# Nadwyzka:  16000 Skladka:  1100 Liczba ruin:  65 Sredni wynik:  57863.0 Prawd_bankr:  0.043333333333333335
# Nadwyzka:  16000 Skladka:  1200 Liczba ruin:  37 Sredni wynik:  66672.0 Prawd_bankr:  0.024666666666666667
# Nadwyzka:  16000 Skladka:  1300 Liczba ruin:  24 Sredni wynik:  76083.0 Prawd_bankr:  0.016
# Nadwyzka:  16000 Skladka:  1400 Liczba ruin:  14 Sredni wynik:  85537.0 Prawd_bankr:  0.009333333333333334
# Nadwyzka:  16000 Skladka:  1500 Liczba ruin:  12 Sredni wynik:  95443.0 Prawd_bankr:  0.008
# Nadwyzka:  16000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  105134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  16000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  115134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  16000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  125134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  16000 Skladka:  1900 Liczba ruin:  5 Sredni wynik:  134960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  16000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  144896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  17000 Skladka:  500 Liczba ruin:  787 Sredni wynik:  18272.0 Prawd_bankr:  0.5246666666666666
# Nadwyzka:  17000 Skladka:  600 Liczba ruin:  565 Sredni wynik:  22664.0 Prawd_bankr:  0.37666666666666665
# Nadwyzka:  17000 Skladka:  700 Liczba ruin:  393 Sredni wynik:  28424.0 Prawd_bankr:  0.262
# Nadwyzka:  17000 Skladka:  800 Liczba ruin:  246 Sredni wynik:  34550.0 Prawd_bankr:  0.164
# Nadwyzka:  17000 Skladka:  900 Liczba ruin:  159 Sredni wynik:  42070.0 Prawd_bankr:  0.106
# Nadwyzka:  17000 Skladka:  1000 Liczba ruin:  95 Sredni wynik:  49969.0 Prawd_bankr:  0.06333333333333334
# Nadwyzka:  17000 Skladka:  1100 Liczba ruin:  63 Sredni wynik:  58789.0 Prawd_bankr:  0.042
# Nadwyzka:  17000 Skladka:  1200 Liczba ruin:  34 Sredni wynik:  67535.0 Prawd_bankr:  0.02266666666666667
# Nadwyzka:  17000 Skladka:  1300 Liczba ruin:  22 Sredni wynik:  76980.0 Prawd_bankr:  0.014666666666666666
# Nadwyzka:  17000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  86505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  17000 Skladka:  1500 Liczba ruin:  11 Sredni wynik:  96379.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  17000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  106134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  17000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  116134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  17000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  126134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  17000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  135896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  17000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  145896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  18000 Skladka:  500 Liczba ruin:  772 Sredni wynik:  18898.0 Prawd_bankr:  0.5146666666666667
# Nadwyzka:  18000 Skladka:  600 Liczba ruin:  543 Sredni wynik:  23141.0 Prawd_bankr:  0.362
# Nadwyzka:  18000 Skladka:  700 Liczba ruin:  375 Sredni wynik:  28964.0 Prawd_bankr:  0.25
# Nadwyzka:  18000 Skladka:  800 Liczba ruin:  233 Sredni wynik:  35223.0 Prawd_bankr:  0.15533333333333332
# Nadwyzka:  18000 Skladka:  900 Liczba ruin:  155 Sredni wynik:  42943.0 Prawd_bankr:  0.10333333333333333
# Nadwyzka:  18000 Skladka:  1000 Liczba ruin:  89 Sredni wynik:  50780.0 Prawd_bankr:  0.059333333333333335
# Nadwyzka:  18000 Skladka:  1100 Liczba ruin:  59 Sredni wynik:  59630.0 Prawd_bankr:  0.03933333333333333
# Nadwyzka:  18000 Skladka:  1200 Liczba ruin:  33 Sredni wynik:  68511.0 Prawd_bankr:  0.022
# Nadwyzka:  18000 Skladka:  1300 Liczba ruin:  22 Sredni wynik:  77980.0 Prawd_bankr:  0.014666666666666666
# Nadwyzka:  18000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  87505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  18000 Skladka:  1500 Liczba ruin:  11 Sredni wynik:  97379.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  18000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  107134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  18000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  117134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  18000 Skladka:  1800 Liczba ruin:  6 Sredni wynik:  127049.0 Prawd_bankr:  0.004
# Nadwyzka:  18000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  136896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  18000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  146896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  19000 Skladka:  500 Liczba ruin:  747 Sredni wynik:  19254.0 Prawd_bankr:  0.498
# Nadwyzka:  19000 Skladka:  600 Liczba ruin:  523 Sredni wynik:  23663.0 Prawd_bankr:  0.3486666666666667
# Nadwyzka:  19000 Skladka:  700 Liczba ruin:  362 Sredni wynik:  29628.0 Prawd_bankr:  0.24133333333333334
# Nadwyzka:  19000 Skladka:  800 Liczba ruin:  216 Sredni wynik:  35750.0 Prawd_bankr:  0.144
# Nadwyzka:  19000 Skladka:  900 Liczba ruin:  148 Sredni wynik:  43718.0 Prawd_bankr:  0.09866666666666667
# Nadwyzka:  19000 Skladka:  1000 Liczba ruin:  84 Sredni wynik:  51598.0 Prawd_bankr:  0.056
# Nadwyzka:  19000 Skladka:  1100 Liczba ruin:  55 Sredni wynik:  60463.0 Prawd_bankr:  0.03666666666666667
# Nadwyzka:  19000 Skladka:  1200 Liczba ruin:  32 Sredni wynik:  69464.0 Prawd_bankr:  0.021333333333333333
# Nadwyzka:  19000 Skladka:  1300 Liczba ruin:  20 Sredni wynik:  78894.0 Prawd_bankr:  0.013333333333333334
# Nadwyzka:  19000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  88505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  19000 Skladka:  1500 Liczba ruin:  10 Sredni wynik:  98313.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  19000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  108134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  19000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  118134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  19000 Skladka:  1800 Liczba ruin:  6 Sredni wynik:  128049.0 Prawd_bankr:  0.004
# Nadwyzka:  19000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  137896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  19000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  147896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  20000 Skladka:  500 Liczba ruin:  729 Sredni wynik:  19796.0 Prawd_bankr:  0.486
# Nadwyzka:  20000 Skladka:  600 Liczba ruin:  508 Sredni wynik:  24298.0 Prawd_bankr:  0.33866666666666667
# Nadwyzka:  20000 Skladka:  700 Liczba ruin:  343 Sredni wynik:  30143.0 Prawd_bankr:  0.22866666666666666
# Nadwyzka:  20000 Skladka:  800 Liczba ruin:  209 Sredni wynik:  36553.0 Prawd_bankr:  0.13933333333333334
# Nadwyzka:  20000 Skladka:  900 Liczba ruin:  136 Sredni wynik:  44343.0 Prawd_bankr:  0.09066666666666667
# Nadwyzka:  20000 Skladka:  1000 Liczba ruin:  82 Sredni wynik:  52525.0 Prawd_bankr:  0.05466666666666667
# Nadwyzka:  20000 Skladka:  1100 Liczba ruin:  52 Sredni wynik:  61337.0 Prawd_bankr:  0.034666666666666665
# Nadwyzka:  20000 Skladka:  1200 Liczba ruin:  29 Sredni wynik:  70322.0 Prawd_bankr:  0.019333333333333334
# Nadwyzka:  20000 Skladka:  1300 Liczba ruin:  20 Sredni wynik:  79894.0 Prawd_bankr:  0.013333333333333334
# Nadwyzka:  20000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  89505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  20000 Skladka:  1500 Liczba ruin:  10 Sredni wynik:  99313.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  20000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  109134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  20000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  119134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  20000 Skladka:  1800 Liczba ruin:  5 Sredni wynik:  128986.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  20000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  138896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  20000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  148896.0 Prawd_bankr:  0.0026666666666666666

# %%
# Powtorka symulacji, lambda +5%
sr_wynik = [] # średni wynik finansowy firmy
odch_stand_wynik = [] # Odch. stand. sredniego wyniku
wysokosc_skladki = []
wysokosc_nadwyzki = []
prawd_bankr = []
liczba_ruin = [] 

LICZBA_POWTORZEN = 1500
LICZBA_KLIENTOW = 100
HORYZONT = 2 # dlugość obowiązywania umowy - zakładamy 2 lata


for nadwyzka in range(5000, 21000, 1000):
    for skladka in range(500, 2100, 100):
        wartosc_f_xy = wywolanie(nadwyzka, skladka, 
                                 LICZBA_POWTORZEN, LICZBA_KLIENTOW, 
                                 SREDNIA_LICZBA_SZKOD , SR_SZKODA_LN, 
                                 STD_SZKODA_LN, HORYZONT)
        wysokosc_skladki.append(skladka)
        wysokosc_nadwyzki.append(nadwyzka)
        liczba_ruin.append(wartosc_f_xy[0])
        prawd_bankr.append(wartosc_f_xy[1])
        sr_wynik.append(wartosc_f_xy[2])
        odch_stand_wynik.append(wartosc_f_xy[3])
        print("Nadwyzka: ", nadwyzka, "Skladka: ", skladka, 
              "Liczba ruin: ", wartosc_f_xy[0], "Sredni wynik: ",
              round(wartosc_f_xy[2]), "Prawd_bankr: ", wartosc_f_xy[1])

tys_piecset = DataFrame.from_dict({'nadwyzka': wysokosc_nadwyzki,
                            'skladka': wysokosc_skladki,
                            'liczba_ruin': liczba_ruin,
                            'prawd_bankr': prawd_bankr,
                            'sr_wynik': sr_wynik,
                            'odch_stand_wynik': odch_stand_wynik},
        orient = 'columns')

tys_piecset.set_index(['nadwyzka', 'skladka'], inplace = True)
# Out:
# Nadwyzka:  5000 Skladka:  500 Liczba ruin:  1060 Sredni wynik:  13618.0 Prawd_bankr:  0.7066666666666667
# Nadwyzka:  5000 Skladka:  600 Liczba ruin:  846 Sredni wynik:  17566.0 Prawd_bankr:  0.564
# Nadwyzka:  5000 Skladka:  700 Liczba ruin:  643 Sredni wynik:  22276.0 Prawd_bankr:  0.42866666666666664
# Nadwyzka:  5000 Skladka:  800 Liczba ruin:  447 Sredni wynik:  27370.0 Prawd_bankr:  0.298
# Nadwyzka:  5000 Skladka:  900 Liczba ruin:  288 Sredni wynik:  33350.0 Prawd_bankr:  0.192
# Nadwyzka:  5000 Skladka:  1000 Liczba ruin:  194 Sredni wynik:  40677.0 Prawd_bankr:  0.12933333333333333
# Nadwyzka:  5000 Skladka:  1100 Liczba ruin:  120 Sredni wynik:  48402.0 Prawd_bankr:  0.08
# Nadwyzka:  5000 Skladka:  1200 Liczba ruin:  84 Sredni wynik:  57147.0 Prawd_bankr:  0.056
# Nadwyzka:  5000 Skladka:  1300 Liczba ruin:  53 Sredni wynik:  65942.0 Prawd_bankr:  0.035333333333333335
# Nadwyzka:  5000 Skladka:  1400 Liczba ruin:  36 Sredni wynik:  75256.0 Prawd_bankr:  0.024
# Nadwyzka:  5000 Skladka:  1500 Liczba ruin:  24 Sredni wynik:  84728.0 Prawd_bankr:  0.016
# Nadwyzka:  5000 Skladka:  1600 Liczba ruin:  19 Sredni wynik:  94525.0 Prawd_bankr:  0.012666666666666666
# Nadwyzka:  5000 Skladka:  1700 Liczba ruin:  13 Sredni wynik:  104210.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  5000 Skladka:  1800 Liczba ruin:  12 Sredni wynik:  114206.0 Prawd_bankr:  0.008
# Nadwyzka:  5000 Skladka:  1900 Liczba ruin:  10 Sredni wynik:  124129.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  5000 Skladka:  2000 Liczba ruin:  7 Sredni wynik:  133962.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  6000 Skladka:  500 Liczba ruin:  1040 Sredni wynik:  14004.0 Prawd_bankr:  0.6933333333333334
# Nadwyzka:  6000 Skladka:  600 Liczba ruin:  827 Sredni wynik:  18076.0 Prawd_bankr:  0.5513333333333333
# Nadwyzka:  6000 Skladka:  700 Liczba ruin:  612 Sredni wynik:  22501.0 Prawd_bankr:  0.408
# Nadwyzka:  6000 Skladka:  800 Liczba ruin:  423 Sredni wynik:  27926.0 Prawd_bankr:  0.282
# Nadwyzka:  6000 Skladka:  900 Liczba ruin:  274 Sredni wynik:  34010.0 Prawd_bankr:  0.18266666666666667
# Nadwyzka:  6000 Skladka:  1000 Liczba ruin:  182 Sredni wynik:  41441.0 Prawd_bankr:  0.12133333333333333
# Nadwyzka:  6000 Skladka:  1100 Liczba ruin:  111 Sredni wynik:  49179.0 Prawd_bankr:  0.074
# Nadwyzka:  6000 Skladka:  1200 Liczba ruin:  80 Sredni wynik:  58056.0 Prawd_bankr:  0.05333333333333334
# Nadwyzka:  6000 Skladka:  1300 Liczba ruin:  48 Sredni wynik:  66818.0 Prawd_bankr:  0.032
# Nadwyzka:  6000 Skladka:  1400 Liczba ruin:  33 Sredni wynik:  76217.0 Prawd_bankr:  0.022
# Nadwyzka:  6000 Skladka:  1500 Liczba ruin:  20 Sredni wynik:  85586.0 Prawd_bankr:  0.013333333333333334
# Nadwyzka:  6000 Skladka:  1600 Liczba ruin:  17 Sredni wynik:  95505.0 Prawd_bankr:  0.011333333333333334
# Nadwyzka:  6000 Skladka:  1700 Liczba ruin:  11 Sredni wynik:  105214.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  6000 Skladka:  1800 Liczba ruin:  10 Sredni wynik:  115169.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  6000 Skladka:  1900 Liczba ruin:  9 Sredni wynik:  125137.0 Prawd_bankr:  0.006
# Nadwyzka:  6000 Skladka:  2000 Liczba ruin:  7 Sredni wynik:  134962.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  7000 Skladka:  500 Liczba ruin:  1016 Sredni wynik:  14284.0 Prawd_bankr:  0.6773333333333333
# Nadwyzka:  7000 Skladka:  600 Liczba ruin:  800 Sredni wynik:  18438.0 Prawd_bankr:  0.5333333333333333
# Nadwyzka:  7000 Skladka:  700 Liczba ruin:  580 Sredni wynik:  22818.0 Prawd_bankr:  0.38666666666666666
# Nadwyzka:  7000 Skladka:  800 Liczba ruin:  405 Sredni wynik:  28563.0 Prawd_bankr:  0.27
# Nadwyzka:  7000 Skladka:  900 Liczba ruin:  260 Sredni wynik:  34683.0 Prawd_bankr:  0.17333333333333334
# Nadwyzka:  7000 Skladka:  1000 Liczba ruin:  171 Sredni wynik:  42176.0 Prawd_bankr:  0.114
# Nadwyzka:  7000 Skladka:  1100 Liczba ruin:  108 Sredni wynik:  50132.0 Prawd_bankr:  0.072
# Nadwyzka:  7000 Skladka:  1200 Liczba ruin:  77 Sredni wynik:  58991.0 Prawd_bankr:  0.051333333333333335
# Nadwyzka:  7000 Skladka:  1300 Liczba ruin:  41 Sredni wynik:  67646.0 Prawd_bankr:  0.027333333333333334
# Nadwyzka:  7000 Skladka:  1400 Liczba ruin:  30 Sredni wynik:  77121.0 Prawd_bankr:  0.02
# Nadwyzka:  7000 Skladka:  1500 Liczba ruin:  18 Sredni wynik:  86567.0 Prawd_bankr:  0.012
# Nadwyzka:  7000 Skladka:  1600 Liczba ruin:  14 Sredni wynik:  96414.0 Prawd_bankr:  0.009333333333333334
# Nadwyzka:  7000 Skladka:  1700 Liczba ruin:  11 Sredni wynik:  106214.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  7000 Skladka:  1800 Liczba ruin:  9 Sredni wynik:  116137.0 Prawd_bankr:  0.006
# Nadwyzka:  7000 Skladka:  1900 Liczba ruin:  8 Sredni wynik:  126145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  7000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  135970.0 Prawd_bankr:  0.004
# Nadwyzka:  8000 Skladka:  500 Liczba ruin:  989 Sredni wynik:  14558.0 Prawd_bankr:  0.6593333333333333
# Nadwyzka:  8000 Skladka:  600 Liczba ruin:  785 Sredni wynik:  19116.0 Prawd_bankr:  0.5233333333333333
# Nadwyzka:  8000 Skladka:  700 Liczba ruin:  554 Sredni wynik:  23267.0 Prawd_bankr:  0.36933333333333335
# Nadwyzka:  8000 Skladka:  800 Liczba ruin:  386 Sredni wynik:  29071.0 Prawd_bankr:  0.25733333333333336
# Nadwyzka:  8000 Skladka:  900 Liczba ruin:  247 Sredni wynik:  35349.0 Prawd_bankr:  0.16466666666666666
# Nadwyzka:  8000 Skladka:  1000 Liczba ruin:  163 Sredni wynik:  43008.0 Prawd_bankr:  0.10866666666666666
# Nadwyzka:  8000 Skladka:  1100 Liczba ruin:  101 Sredni wynik:  50966.0 Prawd_bankr:  0.06733333333333333
# Nadwyzka:  8000 Skladka:  1200 Liczba ruin:  69 Sredni wynik:  59824.0 Prawd_bankr:  0.046
# Nadwyzka:  8000 Skladka:  1300 Liczba ruin:  41 Sredni wynik:  68646.0 Prawd_bankr:  0.027333333333333334
# Nadwyzka:  8000 Skladka:  1400 Liczba ruin:  28 Sredni wynik:  78076.0 Prawd_bankr:  0.018666666666666668
# Nadwyzka:  8000 Skladka:  1500 Liczba ruin:  17 Sredni wynik:  87562.0 Prawd_bankr:  0.011333333333333334
# Nadwyzka:  8000 Skladka:  1600 Liczba ruin:  14 Sredni wynik:  97414.0 Prawd_bankr:  0.009333333333333334
# Nadwyzka:  8000 Skladka:  1700 Liczba ruin:  11 Sredni wynik:  107214.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  8000 Skladka:  1800 Liczba ruin:  8 Sredni wynik:  117145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  8000 Skladka:  1900 Liczba ruin:  7 Sredni wynik:  127060.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  8000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  136970.0 Prawd_bankr:  0.004
# Nadwyzka:  9000 Skladka:  500 Liczba ruin:  965 Sredni wynik:  14966.0 Prawd_bankr:  0.6433333333333333
# Nadwyzka:  9000 Skladka:  600 Liczba ruin:  757 Sredni wynik:  19405.0 Prawd_bankr:  0.5046666666666667
# Nadwyzka:  9000 Skladka:  700 Liczba ruin:  533 Sredni wynik:  23777.0 Prawd_bankr:  0.35533333333333333
# Nadwyzka:  9000 Skladka:  800 Liczba ruin:  372 Sredni wynik:  29731.0 Prawd_bankr:  0.248
# Nadwyzka:  9000 Skladka:  900 Liczba ruin:  227 Sredni wynik:  35879.0 Prawd_bankr:  0.15133333333333332
# Nadwyzka:  9000 Skladka:  1000 Liczba ruin:  154 Sredni wynik:  43759.0 Prawd_bankr:  0.10266666666666667
# Nadwyzka:  9000 Skladka:  1100 Liczba ruin:  93 Sredni wynik:  51736.0 Prawd_bankr:  0.062
# Nadwyzka:  9000 Skladka:  1200 Liczba ruin:  63 Sredni wynik:  60616.0 Prawd_bankr:  0.042
# Nadwyzka:  9000 Skladka:  1300 Liczba ruin:  38 Sredni wynik:  69539.0 Prawd_bankr:  0.025333333333333333
# Nadwyzka:  9000 Skladka:  1400 Liczba ruin:  26 Sredni wynik:  78999.0 Prawd_bankr:  0.017333333333333333
# Nadwyzka:  9000 Skladka:  1500 Liczba ruin:  16 Sredni wynik:  88540.0 Prawd_bankr:  0.010666666666666666
# Nadwyzka:  9000 Skladka:  1600 Liczba ruin:  12 Sredni wynik:  98356.0 Prawd_bankr:  0.008
# Nadwyzka:  9000 Skladka:  1700 Liczba ruin:  10 Sredni wynik:  108221.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  9000 Skladka:  1800 Liczba ruin:  8 Sredni wynik:  118145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  9000 Skladka:  1900 Liczba ruin:  7 Sredni wynik:  128060.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  9000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  137970.0 Prawd_bankr:  0.004
# Nadwyzka:  10000 Skladka:  500 Liczba ruin:  944 Sredni wynik:  15381.0 Prawd_bankr:  0.6293333333333333
# Nadwyzka:  10000 Skladka:  600 Liczba ruin:  738 Sredni wynik:  19938.0 Prawd_bankr:  0.492
# Nadwyzka:  10000 Skladka:  700 Liczba ruin:  516 Sredni wynik:  24383.0 Prawd_bankr:  0.344
# Nadwyzka:  10000 Skladka:  800 Liczba ruin:  350 Sredni wynik:  30211.0 Prawd_bankr:  0.23333333333333334
# Nadwyzka:  10000 Skladka:  900 Liczba ruin:  217 Sredni wynik:  36656.0 Prawd_bankr:  0.14466666666666667
# Nadwyzka:  10000 Skladka:  1000 Liczba ruin:  142 Sredni wynik:  44419.0 Prawd_bankr:  0.09466666666666666
# Nadwyzka:  10000 Skladka:  1100 Liczba ruin:  91 Sredni wynik:  52662.0 Prawd_bankr:  0.06066666666666667
# Nadwyzka:  10000 Skladka:  1200 Liczba ruin:  59 Sredni wynik:  61460.0 Prawd_bankr:  0.03933333333333333
# Nadwyzka:  10000 Skladka:  1300 Liczba ruin:  35 Sredni wynik:  70395.0 Prawd_bankr:  0.023333333333333334
# Nadwyzka:  10000 Skladka:  1400 Liczba ruin:  25 Sredni wynik:  79994.0 Prawd_bankr:  0.016666666666666666
# Nadwyzka:  10000 Skladka:  1500 Liczba ruin:  15 Sredni wynik:  89548.0 Prawd_bankr:  0.01
# Nadwyzka:  10000 Skladka:  1600 Liczba ruin:  12 Sredni wynik:  99356.0 Prawd_bankr:  0.008
# Nadwyzka:  10000 Skladka:  1700 Liczba ruin:  9 Sredni wynik:  109189.0 Prawd_bankr:  0.006
# Nadwyzka:  10000 Skladka:  1800 Liczba ruin:  8 Sredni wynik:  119145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  10000 Skladka:  1900 Liczba ruin:  7 Sredni wynik:  129060.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  10000 Skladka:  2000 Liczba ruin:  6 Sredni wynik:  138970.0 Prawd_bankr:  0.004
# Nadwyzka:  11000 Skladka:  500 Liczba ruin:  926 Sredni wynik:  15898.0 Prawd_bankr:  0.6173333333333333
# Nadwyzka:  11000 Skladka:  600 Liczba ruin:  712 Sredni wynik:  20298.0 Prawd_bankr:  0.4746666666666667
# Nadwyzka:  11000 Skladka:  700 Liczba ruin:  494 Sredni wynik:  24850.0 Prawd_bankr:  0.3293333333333333
# Nadwyzka:  11000 Skladka:  800 Liczba ruin:  333 Sredni wynik:  30793.0 Prawd_bankr:  0.222
# Nadwyzka:  11000 Skladka:  900 Liczba ruin:  202 Sredni wynik:  37261.0 Prawd_bankr:  0.13466666666666666
# Nadwyzka:  11000 Skladka:  1000 Liczba ruin:  136 Sredni wynik:  45222.0 Prawd_bankr:  0.09066666666666667
# Nadwyzka:  11000 Skladka:  1100 Liczba ruin:  87 Sredni wynik:  53548.0 Prawd_bankr:  0.058
# Nadwyzka:  11000 Skladka:  1200 Liczba ruin:  57 Sredni wynik:  62374.0 Prawd_bankr:  0.038
# Nadwyzka:  11000 Skladka:  1300 Liczba ruin:  32 Sredni wynik:  71324.0 Prawd_bankr:  0.021333333333333333
# Nadwyzka:  11000 Skladka:  1400 Liczba ruin:  21 Sredni wynik:  80884.0 Prawd_bankr:  0.014
# Nadwyzka:  11000 Skladka:  1500 Liczba ruin:  15 Sredni wynik:  90548.0 Prawd_bankr:  0.01
# Nadwyzka:  11000 Skladka:  1600 Liczba ruin:  11 Sredni wynik:  100289.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  11000 Skladka:  1700 Liczba ruin:  8 Sredni wynik:  110145.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  11000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  120134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  11000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  130049.0 Prawd_bankr:  0.004
# Nadwyzka:  11000 Skladka:  2000 Liczba ruin:  5 Sredni wynik:  139960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  12000 Skladka:  500 Liczba ruin:  905 Sredni wynik:  16320.0 Prawd_bankr:  0.6033333333333334
# Nadwyzka:  12000 Skladka:  600 Liczba ruin:  690 Sredni wynik:  20742.0 Prawd_bankr:  0.46
# Nadwyzka:  12000 Skladka:  700 Liczba ruin:  475 Sredni wynik:  25428.0 Prawd_bankr:  0.31666666666666665
# Nadwyzka:  12000 Skladka:  800 Liczba ruin:  317 Sredni wynik:  31396.0 Prawd_bankr:  0.21133333333333335
# Nadwyzka:  12000 Skladka:  900 Liczba ruin:  191 Sredni wynik:  37957.0 Prawd_bankr:  0.12733333333333333
# Nadwyzka:  12000 Skladka:  1000 Liczba ruin:  129 Sredni wynik:  45989.0 Prawd_bankr:  0.086
# Nadwyzka:  12000 Skladka:  1100 Liczba ruin:  86 Sredni wynik:  54518.0 Prawd_bankr:  0.05733333333333333
# Nadwyzka:  12000 Skladka:  1200 Liczba ruin:  53 Sredni wynik:  63258.0 Prawd_bankr:  0.035333333333333335
# Nadwyzka:  12000 Skladka:  1300 Liczba ruin:  29 Sredni wynik:  72271.0 Prawd_bankr:  0.019333333333333334
# Nadwyzka:  12000 Skladka:  1400 Liczba ruin:  19 Sredni wynik:  81819.0 Prawd_bankr:  0.012666666666666666
# Nadwyzka:  12000 Skladka:  1500 Liczba ruin:  13 Sredni wynik:  91476.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  12000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  101178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  12000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  111134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  12000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  121134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  12000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  131049.0 Prawd_bankr:  0.004
# Nadwyzka:  12000 Skladka:  2000 Liczba ruin:  5 Sredni wynik:  140960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  13000 Skladka:  500 Liczba ruin:  875 Sredni wynik:  16515.0 Prawd_bankr:  0.5833333333333334
# Nadwyzka:  13000 Skladka:  600 Liczba ruin:  668 Sredni wynik:  21205.0 Prawd_bankr:  0.44533333333333336
# Nadwyzka:  13000 Skladka:  700 Liczba ruin:  460 Sredni wynik:  26056.0 Prawd_bankr:  0.30666666666666664
# Nadwyzka:  13000 Skladka:  800 Liczba ruin:  300 Sredni wynik:  31971.0 Prawd_bankr:  0.2
# Nadwyzka:  13000 Skladka:  900 Liczba ruin:  188 Sredni wynik:  38881.0 Prawd_bankr:  0.12533333333333332
# Nadwyzka:  13000 Skladka:  1000 Liczba ruin:  116 Sredni wynik:  46600.0 Prawd_bankr:  0.07733333333333334
# Nadwyzka:  13000 Skladka:  1100 Liczba ruin:  79 Sredni wynik:  55347.0 Prawd_bankr:  0.05266666666666667
# Nadwyzka:  13000 Skladka:  1200 Liczba ruin:  48 Sredni wynik:  64145.0 Prawd_bankr:  0.032
# Nadwyzka:  13000 Skladka:  1300 Liczba ruin:  27 Sredni wynik:  73198.0 Prawd_bankr:  0.018
# Nadwyzka:  13000 Skladka:  1400 Liczba ruin:  17 Sredni wynik:  82707.0 Prawd_bankr:  0.011333333333333334
# Nadwyzka:  13000 Skladka:  1500 Liczba ruin:  13 Sredni wynik:  92476.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  13000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  102178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  13000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  112134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  13000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  122134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  13000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  132049.0 Prawd_bankr:  0.004
# Nadwyzka:  13000 Skladka:  2000 Liczba ruin:  5 Sredni wynik:  141960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  14000 Skladka:  500 Liczba ruin:  853 Sredni wynik:  16938.0 Prawd_bankr:  0.5686666666666667
# Nadwyzka:  14000 Skladka:  600 Liczba ruin:  653 Sredni wynik:  21821.0 Prawd_bankr:  0.43533333333333335
# Nadwyzka:  14000 Skladka:  700 Liczba ruin:  442 Sredni wynik:  26628.0 Prawd_bankr:  0.2946666666666667
# Nadwyzka:  14000 Skladka:  800 Liczba ruin:  284 Sredni wynik:  32544.0 Prawd_bankr:  0.18933333333333333
# Nadwyzka:  14000 Skladka:  900 Liczba ruin:  183 Sredni wynik:  39765.0 Prawd_bankr:  0.122
# Nadwyzka:  14000 Skladka:  1000 Liczba ruin:  108 Sredni wynik:  47367.0 Prawd_bankr:  0.072
# Nadwyzka:  14000 Skladka:  1100 Liczba ruin:  74 Sredni wynik:  56184.0 Prawd_bankr:  0.04933333333333333
# Nadwyzka:  14000 Skladka:  1200 Liczba ruin:  45 Sredni wynik:  65032.0 Prawd_bankr:  0.03
# Nadwyzka:  14000 Skladka:  1300 Liczba ruin:  25 Sredni wynik:  74125.0 Prawd_bankr:  0.016666666666666666
# Nadwyzka:  14000 Skladka:  1400 Liczba ruin:  16 Sredni wynik:  83651.0 Prawd_bankr:  0.010666666666666666
# Nadwyzka:  14000 Skladka:  1500 Liczba ruin:  12 Sredni wynik:  93443.0 Prawd_bankr:  0.008
# Nadwyzka:  14000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  103178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  14000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  113134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  14000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  123134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  14000 Skladka:  1900 Liczba ruin:  6 Sredni wynik:  133049.0 Prawd_bankr:  0.004
# Nadwyzka:  14000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  142896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  15000 Skladka:  500 Liczba ruin:  833 Sredni wynik:  17439.0 Prawd_bankr:  0.5553333333333333
# Nadwyzka:  15000 Skladka:  600 Liczba ruin:  625 Sredni wynik:  22134.0 Prawd_bankr:  0.4166666666666667
# Nadwyzka:  15000 Skladka:  700 Liczba ruin:  426 Sredni wynik:  27238.0 Prawd_bankr:  0.284
# Nadwyzka:  15000 Skladka:  800 Liczba ruin:  270 Sredni wynik:  33196.0 Prawd_bankr:  0.18
# Nadwyzka:  15000 Skladka:  900 Liczba ruin:  176 Sredni wynik:  40554.0 Prawd_bankr:  0.11733333333333333
# Nadwyzka:  15000 Skladka:  1000 Liczba ruin:  103 Sredni wynik:  48222.0 Prawd_bankr:  0.06866666666666667
# Nadwyzka:  15000 Skladka:  1100 Liczba ruin:  69 Sredni wynik:  56987.0 Prawd_bankr:  0.046
# Nadwyzka:  15000 Skladka:  1200 Liczba ruin:  38 Sredni wynik:  65718.0 Prawd_bankr:  0.025333333333333333
# Nadwyzka:  15000 Skladka:  1300 Liczba ruin:  25 Sredni wynik:  75125.0 Prawd_bankr:  0.016666666666666666
# Nadwyzka:  15000 Skladka:  1400 Liczba ruin:  15 Sredni wynik:  84594.0 Prawd_bankr:  0.01
# Nadwyzka:  15000 Skladka:  1500 Liczba ruin:  12 Sredni wynik:  94443.0 Prawd_bankr:  0.008
# Nadwyzka:  15000 Skladka:  1600 Liczba ruin:  8 Sredni wynik:  104178.0 Prawd_bankr:  0.005333333333333333
# Nadwyzka:  15000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  114134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  15000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  124134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  15000 Skladka:  1900 Liczba ruin:  5 Sredni wynik:  133960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  15000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  143896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  16000 Skladka:  500 Liczba ruin:  812 Sredni wynik:  17894.0 Prawd_bankr:  0.5413333333333333
# Nadwyzka:  16000 Skladka:  600 Liczba ruin:  595 Sredni wynik:  22381.0 Prawd_bankr:  0.39666666666666667
# Nadwyzka:  16000 Skladka:  700 Liczba ruin:  408 Sredni wynik:  27808.0 Prawd_bankr:  0.272
# Nadwyzka:  16000 Skladka:  800 Liczba ruin:  258 Sredni wynik:  33879.0 Prawd_bankr:  0.172
# Nadwyzka:  16000 Skladka:  900 Liczba ruin:  168 Sredni wynik:  41330.0 Prawd_bankr:  0.112
# Nadwyzka:  16000 Skladka:  1000 Liczba ruin:  97 Sredni wynik:  49014.0 Prawd_bankr:  0.06466666666666666
# Nadwyzka:  16000 Skladka:  1100 Liczba ruin:  65 Sredni wynik:  57863.0 Prawd_bankr:  0.043333333333333335
# Nadwyzka:  16000 Skladka:  1200 Liczba ruin:  37 Sredni wynik:  66672.0 Prawd_bankr:  0.024666666666666667
# Nadwyzka:  16000 Skladka:  1300 Liczba ruin:  24 Sredni wynik:  76083.0 Prawd_bankr:  0.016
# Nadwyzka:  16000 Skladka:  1400 Liczba ruin:  14 Sredni wynik:  85537.0 Prawd_bankr:  0.009333333333333334
# Nadwyzka:  16000 Skladka:  1500 Liczba ruin:  12 Sredni wynik:  95443.0 Prawd_bankr:  0.008
# Nadwyzka:  16000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  105134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  16000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  115134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  16000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  125134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  16000 Skladka:  1900 Liczba ruin:  5 Sredni wynik:  134960.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  16000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  144896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  17000 Skladka:  500 Liczba ruin:  787 Sredni wynik:  18272.0 Prawd_bankr:  0.5246666666666666
# Nadwyzka:  17000 Skladka:  600 Liczba ruin:  565 Sredni wynik:  22664.0 Prawd_bankr:  0.37666666666666665
# Nadwyzka:  17000 Skladka:  700 Liczba ruin:  393 Sredni wynik:  28424.0 Prawd_bankr:  0.262
# Nadwyzka:  17000 Skladka:  800 Liczba ruin:  246 Sredni wynik:  34550.0 Prawd_bankr:  0.164
# Nadwyzka:  17000 Skladka:  900 Liczba ruin:  159 Sredni wynik:  42070.0 Prawd_bankr:  0.106
# Nadwyzka:  17000 Skladka:  1000 Liczba ruin:  95 Sredni wynik:  49969.0 Prawd_bankr:  0.06333333333333334
# Nadwyzka:  17000 Skladka:  1100 Liczba ruin:  63 Sredni wynik:  58789.0 Prawd_bankr:  0.042
# Nadwyzka:  17000 Skladka:  1200 Liczba ruin:  34 Sredni wynik:  67535.0 Prawd_bankr:  0.02266666666666667
# Nadwyzka:  17000 Skladka:  1300 Liczba ruin:  22 Sredni wynik:  76980.0 Prawd_bankr:  0.014666666666666666
# Nadwyzka:  17000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  86505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  17000 Skladka:  1500 Liczba ruin:  11 Sredni wynik:  96379.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  17000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  106134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  17000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  116134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  17000 Skladka:  1800 Liczba ruin:  7 Sredni wynik:  126134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  17000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  135896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  17000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  145896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  18000 Skladka:  500 Liczba ruin:  772 Sredni wynik:  18898.0 Prawd_bankr:  0.5146666666666667
# Nadwyzka:  18000 Skladka:  600 Liczba ruin:  543 Sredni wynik:  23141.0 Prawd_bankr:  0.362
# Nadwyzka:  18000 Skladka:  700 Liczba ruin:  375 Sredni wynik:  28964.0 Prawd_bankr:  0.25
# Nadwyzka:  18000 Skladka:  800 Liczba ruin:  233 Sredni wynik:  35223.0 Prawd_bankr:  0.15533333333333332
# Nadwyzka:  18000 Skladka:  900 Liczba ruin:  155 Sredni wynik:  42943.0 Prawd_bankr:  0.10333333333333333
# Nadwyzka:  18000 Skladka:  1000 Liczba ruin:  89 Sredni wynik:  50780.0 Prawd_bankr:  0.059333333333333335
# Nadwyzka:  18000 Skladka:  1100 Liczba ruin:  59 Sredni wynik:  59630.0 Prawd_bankr:  0.03933333333333333
# Nadwyzka:  18000 Skladka:  1200 Liczba ruin:  33 Sredni wynik:  68511.0 Prawd_bankr:  0.022
# Nadwyzka:  18000 Skladka:  1300 Liczba ruin:  22 Sredni wynik:  77980.0 Prawd_bankr:  0.014666666666666666
# Nadwyzka:  18000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  87505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  18000 Skladka:  1500 Liczba ruin:  11 Sredni wynik:  97379.0 Prawd_bankr:  0.007333333333333333
# Nadwyzka:  18000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  107134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  18000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  117134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  18000 Skladka:  1800 Liczba ruin:  6 Sredni wynik:  127049.0 Prawd_bankr:  0.004
# Nadwyzka:  18000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  136896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  18000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  146896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  19000 Skladka:  500 Liczba ruin:  747 Sredni wynik:  19254.0 Prawd_bankr:  0.498
# Nadwyzka:  19000 Skladka:  600 Liczba ruin:  523 Sredni wynik:  23663.0 Prawd_bankr:  0.3486666666666667
# Nadwyzka:  19000 Skladka:  700 Liczba ruin:  362 Sredni wynik:  29628.0 Prawd_bankr:  0.24133333333333334
# Nadwyzka:  19000 Skladka:  800 Liczba ruin:  216 Sredni wynik:  35750.0 Prawd_bankr:  0.144
# Nadwyzka:  19000 Skladka:  900 Liczba ruin:  148 Sredni wynik:  43718.0 Prawd_bankr:  0.09866666666666667
# Nadwyzka:  19000 Skladka:  1000 Liczba ruin:  84 Sredni wynik:  51598.0 Prawd_bankr:  0.056
# Nadwyzka:  19000 Skladka:  1100 Liczba ruin:  55 Sredni wynik:  60463.0 Prawd_bankr:  0.03666666666666667
# Nadwyzka:  19000 Skladka:  1200 Liczba ruin:  32 Sredni wynik:  69464.0 Prawd_bankr:  0.021333333333333333
# Nadwyzka:  19000 Skladka:  1300 Liczba ruin:  20 Sredni wynik:  78894.0 Prawd_bankr:  0.013333333333333334
# Nadwyzka:  19000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  88505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  19000 Skladka:  1500 Liczba ruin:  10 Sredni wynik:  98313.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  19000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  108134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  19000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  118134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  19000 Skladka:  1800 Liczba ruin:  6 Sredni wynik:  128049.0 Prawd_bankr:  0.004
# Nadwyzka:  19000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  137896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  19000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  147896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  20000 Skladka:  500 Liczba ruin:  729 Sredni wynik:  19796.0 Prawd_bankr:  0.486
# Nadwyzka:  20000 Skladka:  600 Liczba ruin:  508 Sredni wynik:  24298.0 Prawd_bankr:  0.33866666666666667
# Nadwyzka:  20000 Skladka:  700 Liczba ruin:  343 Sredni wynik:  30143.0 Prawd_bankr:  0.22866666666666666
# Nadwyzka:  20000 Skladka:  800 Liczba ruin:  209 Sredni wynik:  36553.0 Prawd_bankr:  0.13933333333333334
# Nadwyzka:  20000 Skladka:  900 Liczba ruin:  136 Sredni wynik:  44343.0 Prawd_bankr:  0.09066666666666667
# Nadwyzka:  20000 Skladka:  1000 Liczba ruin:  82 Sredni wynik:  52525.0 Prawd_bankr:  0.05466666666666667
# Nadwyzka:  20000 Skladka:  1100 Liczba ruin:  52 Sredni wynik:  61337.0 Prawd_bankr:  0.034666666666666665
# Nadwyzka:  20000 Skladka:  1200 Liczba ruin:  29 Sredni wynik:  70322.0 Prawd_bankr:  0.019333333333333334
# Nadwyzka:  20000 Skladka:  1300 Liczba ruin:  20 Sredni wynik:  79894.0 Prawd_bankr:  0.013333333333333334
# Nadwyzka:  20000 Skladka:  1400 Liczba ruin:  13 Sredni wynik:  89505.0 Prawd_bankr:  0.008666666666666666
# Nadwyzka:  20000 Skladka:  1500 Liczba ruin:  10 Sredni wynik:  99313.0 Prawd_bankr:  0.006666666666666667
# Nadwyzka:  20000 Skladka:  1600 Liczba ruin:  7 Sredni wynik:  109134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  20000 Skladka:  1700 Liczba ruin:  7 Sredni wynik:  119134.0 Prawd_bankr:  0.004666666666666667
# Nadwyzka:  20000 Skladka:  1800 Liczba ruin:  5 Sredni wynik:  128986.0 Prawd_bankr:  0.0033333333333333335
# Nadwyzka:  20000 Skladka:  1900 Liczba ruin:  4 Sredni wynik:  138896.0 Prawd_bankr:  0.0026666666666666666
# Nadwyzka:  20000 Skladka:  2000 Liczba ruin:  4 Sredni wynik:  148896.0 Prawd_bankr:  0.0026666666666666666

# %%
df2 = concat([dane, piecset, tys_piecset], keys = [1000, 500, 1500], names = ['iteracje'])

# %%
fig, ax = plt.subplots(figsize = (10,5))
df2.loc[(slice(None), 10000, slice(None)),:].reset_index().groupby('iteracje'). \
    plot(x = 'skladka', y = 'sr_wynik', legend = False, fontsize = 12, ax = ax)
ax.set_ylabel('Prawdopodobieństwo bankructwa', fontsize = 12)
ax.set_xlabel('Wysokość składki [PLN]', fontsize = 12)
ax.legend(labels = ['500', '1000', '1500'], title = 'Liczba iteracji', fontsize = 12)

# %%
# Zapisuję do pliku, żeby nie musieć symulować wszystkiego od nowa
dane.to_hdf('dane.hdf', key = 'dane')
lambda_up.to_hdf('dane.hdf', key = 'lambda_up')
lambda_down.to_hdf('dane.hdf', key = 'lambda_down')
piecset.to_hdf('dane.hdf', key = 'piecset')
tys_piecset.to_hdf('dane.hdf', key = 'tys_piecset')
